# %%
# !pip install pytorch_lightning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/My Drive/PyTorch_CIFAR10/')

# %%
import os
from argparse import ArgumentParser

import torch
from pytorch_lightning import Trainer, seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import WandbLogger, TensorBoardLogger
from pytorch_lightning import seed_everything
from data import CIFAR10Data# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = "682/assignment2/assignment2"
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs682/datasets/
# !bash get_datasets.sh 
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs682/
# !python setup.py build_ext --inplace
# %cd /content/drive/My\ Drive/$FOLDERNAME
from module import CIFAR10Module
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/682/assignment2/assignment2/cs682/datasets
# /content/drive/My Drive/682/assignment2/assignment2/cs682
# Compiling im2col_cython.pyx because it depends on /usr/local/lib/python3.7/dist-packages/Cython/Includes/libc/string.pxd.
# [1/1] Cythonizing im2col_cython.pyx
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/My Drive/682/assignment2/assignment2/cs682/im2col_cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'im2col_cython' extension
# ...

# %%
# %cd '/content/drive/My Drive/PyTorch_CIFAR10/'
# Out:
# /content/drive/My Drive/PyTorch_CIFAR10

# %%
# !python train.py --download_weights 1
# Out:
# <class 'argparse.Namespace'>
# Namespace(batch_size=256, classifier='resnet18', data_dir='/data/huy/cifar10', dev=0, download_weights=1, gpu_id='0', learning_rate=0.01, logger='tensorboard', max_epochs=100, num_workers=8, precision=32, pretrained=0, test_phase=0, weight_decay=0.01)
#  12% 120M/979M [00:14<00:35, 24.2MMiB/s]Traceback (most recent call last):
#   File "train.py", line 232, in <module>
#     main(args)
#   File "train.py", line 37, in main
#     CIFAR10Data.download_weights()
#   File "/content/drive/My Drive/PyTorch_CIFAR10/data.py", line 35, in download_weights
#     f.write(data)
# KeyboardInterrupt
#  12% 121M/979M [00:15<01:48, 7.91MMiB/s]

# %%
# !python train.py --test_phase 1 --pretrained 1 --classifier resnet18 --gpu_id 0
# Out:
# <class 'argparse.Namespace'>
# Namespace(batch_size=256, classifier='resnet18', data_dir='/data/huy/cifar10', dev=0, download_weights=0, gpu_id='0', learning_rate=0.01, logger='tensorboard', max_epochs=100, num_workers=8, precision=32, pretrained=1, test_phase=1, weight_decay=0.01)
# Global seed set to 0
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:148: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f0109a39d90>)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f0109a39d90>)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# ...

# %%
import torch 
loaded_model = torch.load("model1.pth")
loaded_model.eval()
# Out:
# CIFAR10Module(
#   (criterion): CrossEntropyLoss()
#   (accuracy): Accuracy()
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
# ...

# %%
# !python load_and_test.py
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Total params:  11173972
# Zero params:  5582176
# Sparsity of model1 50
# Files already downloaded and verified
# ...
